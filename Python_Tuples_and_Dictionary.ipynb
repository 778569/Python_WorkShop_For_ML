# %% [markdown]
# We cant chnages the tuple walues (tuple is a read only list)- cant Append, cant chnage the index myTup[0] = 10,

# %%
Tup01 = (10,20,30,40,50,60)
Tup02 =('a','b','c','d')

print(Tup01[0])
# Out:
# 10

# %%
Tup03 = Tup01 + Tup02
print(Tup03)
# Out:
# (10, 20, 30, 40, 50, 60, 'a', 'b', 'c', 'd')

# %%
Tup03 =list(Tup02)
print(Tup03)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# **Dictionary**
#
# Using {}, Key and value paires , keys are unique
#
# ![image.png](data:image/png;base64,...)

# %%
student = {'name' : "Kavinda", "math" : 76,"Chemistry" : 85, "Physics" : 90}

print(student['name'])
# Out:
# Kavinda

# %%
student['name'] = 'Shakuni'
print(student['name'])
print(student)
# Out:
# Shakuni
# {'name': 'Shakuni', 'math': 76, 'Chemistry': 85, 'Physics': 90}

# %%
student['avg'] = (student['Chemistry'] + student['math'] + student['Physics'])/3
print(student)
# Out:
# {'name': 'Shakuni', 'math': 76, 'Chemistry': 85, 'Physics': 90, 'avg': 83.66666666666667}

# %%
student['math'] = 95
print(student)
# Out:
# {'name': 'Shakuni', 'math': 95, 'Chemistry': 85, 'Physics': 90, 'avg': 83.66666666666667}

# %%
list01 = ['name','phy','chem','bio']
list02 = ['Kavinda',86,79,95]

# %%
dic01 = dict(zip(list01,list02))
print(dic01)
# Out:
# {'name': 'Kavinda', 'phy': 86, 'chem': 79, 'bio': 95}
